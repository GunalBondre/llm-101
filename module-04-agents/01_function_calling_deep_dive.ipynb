# %% [markdown]
# # Function Calling Deep Dive
# ### LLM 101 — Module 4 — Agents
#
# > Build weather agents and calculator agents using LLM function calling.
#
# ---
#
# ## 📺 Watch the episode first
# Follow along with the YouTube video before running cells.
#
# ## ⚙️ Setup
# Make sure your virtual environment is active and `.env` is configured:
# ```bash
# source .venv/bin/activate
# ```
#
# ---
#
# ## 🚧 Coming Soon
# This notebook will be released with its companion YouTube episode.

# %%
# Notebook content coming with the episode!
print('Stay tuned 🚀')
